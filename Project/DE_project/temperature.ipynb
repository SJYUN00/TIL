# %%
import pandas as pd 

from copy import deepcopy

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
west_temp = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/2조/김용현/완료data/수온/서해바다 지역별 수온측정.csv')
east_temp = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/2조/김용현/완료data/수온/동해바다 지역별 수온측정.csv')
south_temp = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/2조/김용현/완료data/수온/남해바다 지역별 수온측정.csv')

# %%
west_temp
# Out:
#        지역별      군산      대산      목포  ...     어청도      인천      평택     흑산도
# 0   201901   4.398  11.085   6.008  ...   6.919   1.955   8.331   7.744
# 1   201902   5.032   4.486   6.006  ...   5.977   4.176   4.140   7.754
# 2   201903   9.001   6.335   9.441  ...   6.955   7.720   8.031   9.000
# 3   201904  12.574   9.099  12.833  ...   9.530  11.637  11.748  10.505
# 4   201905  17.759  13.721  18.030  ...  -1.192  17.866  17.718  13.442
# 5   201906  22.118  17.392  21.867  ...  18.727  22.153  21.680  14.821
# 6   201907  24.736  20.620  23.044  ...  23.626  25.441  24.161  21.202
# 7   201908  26.035  24.069  24.735  ...  23.863  26.359  25.584  20.841
# 8   201909  22.857  22.334  22.202  ...  19.655  23.140  23.135  19.923
# 9   201910  17.892  18.668  18.926  ...  17.510  17.968  18.392  17.374
# 10  201911  11.275  13.368  13.282  ...  13.856  10.777  11.560  13.291
# 11  201912   6.410   8.447   8.912  ...   9.612   6.020   6.395  10.328
# ...

# %%
east_temp.drop('지역별',axis = 1,inplace = True)
south_temp.drop('지역별',axis = 1,inplace = True)

# %%
all_temp = pd.concat([west_temp, east_temp, south_temp], axis = 1)
print(all_temp)
# Out:
#        지역별      군산      대산      목포  ...      제주      진도     추자도      통영
# 0   201901   4.398  11.085   6.008  ...  15.156   7.372  11.347   8.071
# 1   201902   5.032   4.486   6.006  ...  14.674   7.571  11.900   9.639
# 2   201903   9.001   6.335   9.441  ...  14.891   9.793  12.317  12.774
# 3   201904  12.574   9.099  12.833  ...  16.150  12.654  13.924  14.916
# 4   201905  17.759  13.721  18.030  ...  18.182  17.235  16.005  18.436
# 5   201906  22.118  17.392  21.867  ...  20.854  20.267  18.085  21.281
# 6   201907  24.736  20.620  23.044  ...  26.158  22.527  20.609  23.520
# 7   201908  26.035  24.069  24.735  ...  25.522  21.286  20.486  24.703
# 8   201909  22.857  22.334  22.202  ...  23.030  21.710  22.268  22.984
# 9   201910  17.892  18.668  18.926  ...  21.272  18.860  18.255  19.576
# 10  201911  11.275  13.368  13.282  ...  18.681  12.964  15.243  14.631
# 11  201912   6.410   8.447   8.912  ...  16.053   9.725  13.211  10.205
# ...

# %%
all_temp.to_excel('/content/drive/MyDrive/멀티캠퍼스/2조/윤성준/수온수정.xlsx')
